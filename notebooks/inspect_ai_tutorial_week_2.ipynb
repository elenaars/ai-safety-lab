# %% [markdown]
# # Tutorial 2: Evaluating LLMs on MMLU
#
# Welcome to the second tutorial in our AI Safety Evaluations course.
#
# Benchmark evaluation is a core skill in applied ML, but the statistical side is often
# treated as an afterthought — a single accuracy number gets reported, and model differences
# are treated as real without checking whether they could arise from chance alone.
# In this tutorial you will get hands-on experience running evaluations with the inspect_ai
# library and applying basic statistical methods to interpret the results rigorously.
#
# **What you'll learn:**
#
# - Load and prepare a benchmark dataset
# - Compute confidence intervals for accuracy
# - Compare models statistically
# - Perform power analysis to plan evaluation size
#
# **By the end:** **You'll have a statistically rigorous evaluation pipeline that can tell you not just how accurate a model is, but whether observed differences between models are real.**

# %% [markdown]
# ## 1. Setup

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
from scipy import stats
from string import ascii_uppercase
from typing import Tuple, List

from inspect_ai import Task, task, eval
from inspect_ai.dataset import Sample, hf_dataset, FieldSpec
from inspect_ai.solver import multiple_choice, chain_of_thought
from inspect_ai.scorer import choice
from inspect_ai.log import EvalLog

# %%
# Configure models -- replace with what is available in your environment.
# Examples: 'ollama/llama3.2', 'openai/gpt-4o-mini', 'anthropic/claude-haiku-4-5'

MODEL_A = "ollama/llama2"        # weaker / baseline model
MODEL_B = "ollama/qwen2.5:0.5b"  # stronger / comparison model

# %% [markdown]
# ## 2. Loading MMLU
#
# `hf_dataset` is inspect_ai's loader for Hugging Face datasets. It downloads the data
# and wraps each record in a `Sample` -- the standard container that flows through every
# inspect_ai pipeline. A `Sample` carries the model input, the expected target, optional
# answer choices, and arbitrary metadata you want to keep around.
#
# MMLU stores the correct answer as an integer (0 = A, 1 = B, 2 = C, 3 = D).
# The quickest way to load a dataset is with `FieldSpec`, which maps column names to
# `Sample` fields. Let's try it first and see what we get.

# %%
dataset_raw = hf_dataset(
    path="cais/mmlu",
    name="all",
    split="test",
    sample_fields=FieldSpec(
        input="question",
        target="answer",           # raw MMLU answer is an integer index 0-3
        metadata=["choices", "subject"]
    ),
    cached=True
)

sample = dataset_raw[0]
print("input   :", sample.input[:80], "...")
print("target  :", sample.target,  "  <- integer index, not a letter!")
print("choices :", sample.metadata.get("choices"))
# Out:
# input   : Find the degree for the given field extension Q(sqrt(2), sqrt(3), sqrt(18)) over ...
# target  : 1   <- integer index, not a letter!
# choices : ['0', '4', '2', '6']

# %% [markdown]
# The `target` came out as an integer -- but inspect_ai's `multiple_choice()` solver
# and `choice()` scorer expect it to be a letter (`"A"`, `"B"`, `"C"`, or `"D"`).
# When the automatic mapping isn't enough, inspect_ai lets you pass a
# **record-to-sample function** that receives the full raw record and returns a `Sample`
# you construct yourself.

# %%
def record_to_sample(record: dict) -> Sample:
    """
    Convert a raw MMLU record to an inspect_ai Sample.

    MMLU stores the correct answer as an integer index (0=A, 1=B, 2=C, 3=D).
    We convert it to the corresponding uppercase letter so it matches the
    format expected by the choice() scorer.
    """
    answer_idx = int(record["answer"])
    return Sample(
        input=record["question"],
        choices=record["choices"],
        target=ascii_uppercase[answer_idx],   # 0->'A', 1->'B', ...
        metadata=dict(subject=record.get("subject"))
    )


dataset = hf_dataset(
    path="cais/mmlu",
    name="all",
    split="test",
    sample_fields=record_to_sample,
    cached=True
)

sample = dataset[0]
print("target  :", sample.target, " <- letter now")
print("choices :", sample.choices)
# Out:
# target  : B  <- letter now
# choices : ['0', '4', '2', '6']

# %% [markdown]
# ## Assignment 1: Create your working subset
#
# All experiments in this notebook will run on a subject subset small enough to evaluate
# quickly. `Dataset.filter()` takes a predicate over `Sample` objects; the `metadata`
# field gives access to anything set in `record_to_sample` -- here, the MMLU subject tag.
#
# We define `astronomy_subset` as a reference example. Pick any subject or subjects from the [MMLU subject list](https://huggingface.co/datasets/cais/mmlu#task-descriptions) with at least 50 questions so later analyses are statistically meaningful. Create MY_SUBSET and use it in all subsequent exercises.

# %%
# Reference subset used in worked examples
astronomy_subset = dataset.filter(
    lambda s: s.metadata.get("subject") == "astronomy"
)
print(f"Astronomy: {len(astronomy_subset)} questions")


MY_SUBSET = dataset.filter(
    lambda  s: s.metadata.get("subject") == "high_school_statistics"
)

print(f"My subset: {len(MY_SUBSET)} questions")
# Out:
# Astronomy: 152 questions
# My subset: 216 questions

# %% [markdown]
# ## 3. Running an evaluation
#
# Every inspect_ai evaluation is described by a `Task`, which bundles three things:
#
# - **dataset** -- the questions
# - **solver** -- the chain of steps that produces a model response;
#   `multiple_choice()` formats the prompt with lettered options and parses the model's choice
# - **scorer** -- the function that grades the response;
#   `choice()` checks whether the selected letter matches the target
#
# The `@task` decorator registers the function so inspect_ai can discover it by name
# from the CLI or pass it directly to `eval()`.

# %%
@task
def mmlu_subset(subset):
    """Minimal MMLU task for any subject subset."""
    return Task(
        dataset=subset,
        solver=[multiple_choice()],
        scorer=choice()
    )

# %% [markdown]
# Calling `eval()` runs the task and returns a **list of `EvalLog` objects** -- one per
# (task, model) pair. Everything you need is in this object; there is no need to read
# log files from disk.
#
# The two most useful attributes:
# - `log.results.scores` -- list of scorer results, each with a `metrics` dict
#   (`"accuracy"`, `"stderr"`, etc.)
# - `log.samples` -- list of `EvalSample` objects with per-question inputs, outputs, and scores

# %%
logs: List[EvalLog] = eval(
    mmlu_subset(MY_SUBSET),
    model=MODEL_A,
    limit=10        # evaluate only the first 10 questions
)

log = logs[0]      # one task -> one log
print("Status  :", log.status)
print("Model   :", log.eval.model)
print("Accuracy:", log.results.scores[0].metrics["accuracy"].value)
# Out:
# Output()
# [04/12/26 14:02:33] ERROR    Exception in callback Task.__step()                                ]8;id=400422;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=941388;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Status  : success
# Model   : ollama/llama2
# Accuracy: 0.4

# %% [markdown]
# ## 4. From `EvalLog` to a DataFrame
#
# ## Assignment 2: Implement `log_to_df`
#
# The aggregate accuracy in `log.results` is useful for a quick check, but for the
# statistical analyses ahead we need a flat table: **one row per (question, epoch)**
# with a numeric `score` column.
#
# `log.samples` is a list of `EvalSample` objects. Each one has:
# - `.id` -- question identifier
# - `.epoch` -- which run this belongs to (relevant when `epochs > 1`)
# - `.scores` -- a dict mapping scorer name to `Score`; the `Score.value` for `choice()` is
#   `"C"` (correct) or `"I"` (incorrect)
# - `.metadata` -- the metadata dict you set in `record_to_sample`
#
# Implement `log_to_df` so that it converts an `EvalLog` into a DataFrame with columns
# `id`, `epoch`, `score` (1/0), and `subject`. The smoke test below will verify the shape.

# %%
def log_to_df(log: EvalLog) -> pd.DataFrame:
    """
    Convert an EvalLog to a DataFrame with one row per (question, epoch).

    Columns:
        id      – question identifier
        epoch   – epoch index (0 if epochs=1)
        score   – 1 if correct, 0 otherwise
        subject – MMLU subject tag from metadata

    The choice() scorer stores the result as "C" (correct) or "I" (incorrect).
    """

    rows = []
    for sample in log.samples:
        rows.append({"id":sample.id, "epoch": sample.epoch, "score": 1 if sample.scores["choice"].value == 'C' else 0, "subject": sample.metadata["subject"]})
    df = pd.DataFrame(rows)
    return df

# =================================== TESTS ===================================
df_test = log_to_df(log)

assert set(df_test.columns) >= {"id", "epoch", "score", "subject"}
assert df_test["score"].isin([0, 1]).all()
assert len(df_test) == 10

print(df_test.head())
print(f"\nAccuracy: {df_test['score'].mean():.1%}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 21
#      18     return df
#      20 # =================================== TESTS ===================================
# ---> 21 df_test = log_to_df(log)
#      23 assert set(df_test.columns) >= {"id", "epoch", "score", "subject"}
#      24 assert df_test["score"].isin([0, 1]).all()
#
# NameError: name 'log' is not defined

# %% [markdown]
# ## 5. Confidence intervals
#
#
# A single accuracy number carries uncertainty: the eval used a finite set of questions
# sampled from a much larger space. The paper (ss2.1, ss3.1) shows how to quantify this
# using the CLT standard error.
#
#
# ## Assignment 3: Implement `ci_accuracy_basic` and `ci_accuracy`
#
# **`ci_accuracy_basic(scores, ci)`** -- the simple case where every question is answered
# exactly once. `scores` is a plain numpy array of 0s and 1s. Use Eq. 1 from the paper.
#
# **`ci_accuracy(df, ci)`** -- the general case that handles multiple runs per question
# (`epochs > 1`). When K runs exist for a question, average their scores first, then
# compute the SE across question-level averages. Pooling all K×n individual answers
# would undercount variance -- answers to the same question across epochs are correlated.

# %%
import math
from scipy.stats import norm

def ci_accuracy_basic(scores: np.ndarray, ci: float = 0.95) -> Tuple[float, float, float]:
    """
    CLT-based confidence interval for accuracy -- single run per question (K = 1).

    Parameters
    ----------
    scores : 1-D array of per-question binary scores (0 or 1)
    ci     : confidence level (default 0.95)

    Returns
    -------
    (lower_bound, mean_accuracy, upper_bound)
    """
    n = len(scores)
    if n==0 or n==1:
        raise ValueError("scores must contain at least 2 observations")
    mean_accuracy = np.mean(scores)

    var = (1/(n-1))*sum((score - mean_accuracy)**2 for score in scores)
    se_clt = math.sqrt(var/n)

    z = norm.ppf((1 + ci) / 2)
    margin = z * se_clt
    lower_bound = mean_accuracy - margin
    upper_bound = mean_accuracy + margin
    return float(lower_bound), float(mean_accuracy), float(upper_bound)

# scores = np.array([1, 0, 1, 1, 0])
# print(ci_accuracy_basic(scores, 0.95))


def ci_accuracy(df: pd.DataFrame, ci: float = 0.95) -> Tuple[float, float, float]:
    """
    CLT-based confidence interval for accuracy, supporting multiple epochs (K >= 1).

    Parameters
    ----------
    df : DataFrame returned by log_to_df, with columns 'id', 'score', 'epoch'
    ci : confidence level (default 0.95)

    Returns
    -------
    (lower_bound, mean_accuracy, upper_bound)
    """
    per_question = df.groupby("id")["score"].mean()
    print(per_question)
    print(type(per_question))
    print(len(per_question))
    return ci_accuracy_basic(per_question, ci)

# %%
# =================================== TESTS ===================================
def _make_df(ids, scores, epochs=None):
    if epochs is None:
        epochs = [0] * len(ids)
    return pd.DataFrame({"id": ids, "score": scores, "epoch": epochs})

# ci_accuracy_basic
l, m, u = ci_accuracy_basic(np.ones(10))

assert l == 1.0 and u == 1.0, "perfect accuracy: CI should collapse to 1"

l, m, u = ci_accuracy_basic(np.zeros(10))

assert l == 0.0 and u == 0.0, "zero accuracy: CI should collapse to 0"

scores3 = np.array([1, 1, 0, 1, 0], dtype=float)
l, m, u = ci_accuracy_basic(scores3)

assert l < 0.6 < u, f"0.6 not in [{l:.3f}, {u:.3f}]"

np.random.seed(42)
s = np.random.binomial(1, 0.75, 200).astype(float)
l95, _, u95 = ci_accuracy_basic(s, 0.95)
l99, _, u99 = ci_accuracy_basic(s, 0.99)

assert (u99 - l99) > (u95 - l95), "99% CI must be wider than 95%"

# loosen the assertions according to the telegram discussion with the author
assert np.abs(l95 - 0.6819421067148456) < 0.01
assert np.abs(u95 - 0.8080578932851544) < 0.01

# ci_accuracy (K=1 should match basic)
df3 = _make_df([1,2,3,4,5], scores3.tolist())
l_df, _, u_df = ci_accuracy(df3)
l_ar, _, u_ar = ci_accuracy_basic(scores3)

assert np.isclose(l_df, l_ar) and np.isclose(u_df, u_ar), "K=1 must match basic version"

# ci_accuracy (K=3 should give narrower CI on average)
np.random.seed(0)
rows_k1, rows_k3 = [], []
for q in range(30):
    p = np.random.uniform(0.3, 0.9)
    rows_k1.append({"id": q, "score": int(np.random.binomial(1, p)), "epoch": 0})
    for e in range(3):
        rows_k3.append({"id": q, "score": int(np.random.binomial(1, p)), "epoch": e})

l1, _, u1 = ci_accuracy(pd.DataFrame(rows_k1))
l3, _, u3 = ci_accuracy(pd.DataFrame(rows_k3))
print(f"K=1 width: {u1-l1:.3f}")
print(f"K=3 width: {u3-l3:.3f}  (narrower on average)")
print("\n✓ All tests passed!")
# Out:
# id
# 1    1.0
# 2    1.0
# 3    0.0
# 4    1.0
# 5    0.0
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 5
# id
# 0     0.0
# 1     1.0
# 2     1.0
# 3     0.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     1.0
# 8     1.0
# 9     1.0
# 10    1.0
# 11    1.0
# 12    0.0
# 13    0.0
# 14    1.0
# 15    0.0
# 16    0.0
# 17    0.0
# 18    1.0
# 19    0.0
# 20    1.0
# 21    1.0
# 22    0.0
# 23    0.0
# 24    1.0
# 25    1.0
# 26    1.0
# 27    1.0
# 28    1.0
# 29    1.0
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 30
# id
# 0     1.000000
# 1     0.333333
# 2     0.666667
# 3     1.000000
# 4     1.000000
# 5     0.666667
# 6     0.333333
# 7     0.333333
# 8     0.333333
# 9     1.000000
# 10    0.666667
# 11    0.000000
# 12    0.333333
# 13    0.666667
# 14    0.666667
# 15    0.000000
# 16    0.666667
# 17    0.666667
# 18    0.333333
# 19    0.333333
# 20    0.333333
# 21    0.666667
# 22    0.333333
# 23    0.000000
# 24    0.666667
# 25    1.000000
# 26    1.000000
# 27    1.000000
# 28    0.666667
# 29    0.333333
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 30
# K=1 width: 0.343
# K=3 width: 0.227  (narrower on average)
#
# ✓ All tests passed!

# %% [markdown]
# ## 6. Visualising how CIs shrink
#
# Two things make confidence intervals narrower: more questions (larger n) and more
# runs per question (larger K). Your task is to visualise those effects.
#
# ## Assignment 4.1: Plot CI width vs number of epochs

# %%
k_values    = [5, 6, 7, 8, 9, 10]
accuracies    = []
ci_lowers     = []
ci_uppers     = []

for k in k_values:
    logs: List[EvalLog] = eval(
    mmlu_subset(MY_SUBSET),
    model=MODEL_A,
    limit=100,         # I've limited it due to time constraints
    epochs=k,
    )
    df = log_to_df(logs[0])
    lower, mean, upper = ci_accuracy(df)
    accuracies.append(mean)
    ci_lowers.append(lower)
    ci_uppers.append(upper)

plt.figure(figsize=(8, 4))
plt.fill_between(k_values, ci_lowers, ci_uppers, alpha=0.25, label="95% CI")
plt.plot(k_values, accuracies, "o-", lw=2, label="Accuracy")
plt.xlabel("Number of runs per question (K)")
plt.ylabel("Accuracy")
plt.title(f"{MODEL_A} on MMLU-subset — accuracy and CI vs k")
plt.legend()
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# Output()
# [04/12/26 15:58:10] ERROR    Exception in callback Task.__step()                                ]8;id=413029;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=599640;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# [04/12/26 17:00:42] ERROR    Exception in callback Task.__step()                                ]8;id=184414;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=202684;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
# {'choice': Score(value='C', answer='B', explanation='ANSWER: B) 2P(t > 1.54) with df = 6', metadata=None, history=[])}
# <class 'dict'>
# dict_keys(['choice'])
# value='C' answer='B' explanation='ANSWER: B) 2P(t > 1.54) with df = 6' metadata=None history=[]
# C
# id
# 1      1.0
# 2      1.0
# 3      0.0
# 4      0.0
# 5      0.4
#       ...
# 96     0.0
# 97     0.0
# 98     1.0
# 99     0.2
# 100    0.0
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100
# [04/12/26 17:01:06] ERROR    Task was destroyed but it is pending!                              ]8;id=294515;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=397738;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-7742'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:60> wait_for=<Task pending name='Task-7743'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# /usr/lib/python3.12/functools.py:52: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   value = getattr(wrapped, attr)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=682951;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=648316;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-7743' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# [04/12/26 18:14:21] ERROR    Exception in callback Task.__step()                                ]8;id=586896;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=706386;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=460730;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=556306;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-12059'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:57> wait_for=<Task pending name='Task-12060'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# /usr/lib/python3.12/threading.py:299: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   def __enter__(self):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=698876;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=518848;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-12060' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# {'choice': Score(value='C', answer='B', explanation='ANSWER: B', metadata=None, history=[])}
# <class 'dict'>
# dict_keys(['choice'])
# value='C' answer='B' explanation='ANSWER: B' metadata=None history=[]
# C
# id
# 1      1.000000
# 2      0.666667
# 3      0.000000
# 4      0.000000
# 5      0.333333
#          ...
# 96     0.000000
# 97     0.000000
# 98     1.000000
# 99     0.333333
# 100    0.166667
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# [04/12/26 19:26:11] ERROR    Exception in callback Task.__step()                                ]8;id=584962;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=331154;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
# {'choice': Score(value='C', answer='B', explanation='ANSWER: B) 2P(t > 1.54) with df = 6', metadata=None, history=[])}
# <class 'dict'>
# dict_keys(['choice'])
# value='C' answer='B' explanation='ANSWER: B) 2P(t > 1.54) with df = 6' metadata=None history=[]
# C
# id
# 1      1.000000
# 2      0.428571
# 3      0.142857
# 4      0.000000
# 5      0.285714
#          ...
# 96     0.000000
# 97     0.000000
# 98     1.000000
# 99     0.428571
# 100    0.000000
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100
# [04/12/26 19:26:28] ERROR    Task was destroyed but it is pending!                              ]8;id=373888;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=277348;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-17076'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:60> wait_for=<Task pending name='Task-17077'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/inspect_ai/log/_condense.py:313: RuntimeWarning:
# coroutine 'Kernel.shell_main' was never awaited
#   return [walk_event(event, content_fn, context) for event in events]
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=653573;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=110891;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-17077' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# [04/12/26 20:56:58] ERROR    Exception in callback Task.__step()                                ]8;id=155310;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=342199;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
# {'choice': Score(value='C', answer='B', explanation='ANSWER: B', metadata=None, history=[])}
# <class 'dict'>
# dict_keys(['choice'])
# value='C' answer='B' explanation='ANSWER: B' metadata=None history=[]
# C
# id
# 1      1.000
# 2      0.750
# 3      0.000
# 4      0.000
# 5      0.250
#        ...
# 96     0.000
# 97     0.000
# 98     1.000
# 99     0.375
# 100    0.000
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100
# [04/12/26 20:57:25] ERROR    Task was destroyed but it is pending!                              ]8;id=241596;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=249197;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-22793'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:60> wait_for=<Task pending name='Task-22794'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# /usr/lib/python3.12/typing.py:392: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   @functools.wraps(func)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=401427;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=627966;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-22794' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# {'choice': Score(value='C', answer='B', explanation='ANSWER: B) 2P(t > 1.54) with df = 6', metadata=None, history=[])}
# <class 'dict'>
# dict_keys(['choice'])
# value='C' answer='B' explanation='ANSWER: B) 2P(t > 1.54) with df = 6' metadata=None history=[]
# C
# id
# 1      1.000000
# 2      0.888889
# 3      0.111111
# 4      0.000000
# 5      0.555556
#          ...
# 96     0.000000
# 97     0.000000
# 98     1.000000
# 99     0.555556
# 100    0.000000
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100
# [04/12/26 22:34:56] ERROR    Exception in callback Task.__step()                                ]8;id=697961;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=67555;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7abb8c4e5d80> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'choice': Score(value='C', answer='B', explanation='ANSWER: B) 2P(t > 1.54) with df = 6', metadata=None, history=[])}
# <class 'dict'>
# dict_keys(['choice'])
# value='C' answer='B' explanation='ANSWER: B) 2P(t > 1.54) with df = 6' metadata=None history=[]
# C
# id
# 1      0.9
# 2      0.9
# 3      0.0
# 4      0.0
# 5      0.4
#       ...
# 96     0.0
# 97     0.0
# 98     1.0
# 99     0.3
# 100    0.1
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100

# %% [markdown]
# ---
# 1. Look at how fast the band narrows.
#    At what point does running another epoch stop being worth it?
# 2. Does more K change your estimate of the model's accuracy, or just your confidence in it?
# 3. What does this tell you about how to allocate your evaluation budget?
#
# **Your answer:** It looks like 5 epochs were enough. Increasing did not improve. This tells us that questions are answered stably (there are difficult questions that are likely to be answered wrong, and easy questions that are likely to be answered correclty) so question-to-question variation dominates over run-to-run variation.

# %% [markdown]
# ## Assignment 4.2: Compute and plot CI width vs n
#
# For each sample size n in `range(10, len(question_ids)+1, 10)`, slice both DataFrames
# to the first n question IDs, compute `ci_accuracy`, and record the CI width.
# Then plot width vs n.

# %%
question_ids  = pd.unique(df["id"]).tolist()
dataset_sizes = range(10, len(question_ids) + 1, 10)
accuracies    = []
ci_lowers     = []
ci_uppers     = []

for n in range(10, len(question_ids) + 1, 10):
    ids_n = question_ids[:n]
    df_n = df[df["id"].isin(ids_n)]
    lower, mean, upper = ci_accuracy(df_n)
    accuracies.append(mean)
    ci_lowers.append(lower)
    ci_uppers.append(upper)


plt.figure(figsize=(8, 4))
plt.fill_between(dataset_sizes, ci_lowers, ci_uppers, alpha=0.25, label="95% CI")
plt.plot(dataset_sizes, accuracies, "o-", lw=2, label="Accuracy")
plt.xlabel("Number of questions (n)")
plt.ylabel("Accuracy")
plt.title(f"{MODEL_A} on MMLU-subset — accuracy and CI vs n")
plt.legend()
plt.grid(True, alpha=0.4)
plt.tight_layout()
plt.show()
# Out:
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
# 6     0.0
# 7     0.0
# 8     0.1
# 9     0.9
# 10    0.7
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 10
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
# 6     0.0
# 7     0.0
# 8     0.1
# 9     0.9
# 10    0.7
# 11    0.0
# 12    0.0
# 13    0.0
# 14    0.8
# 15    0.0
# 16    0.9
# 17    0.2
# 18    0.0
# 19    0.0
# 20    0.0
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 20
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
# 6     0.0
# 7     0.0
# 8     0.1
# 9     0.9
# 10    0.7
# 11    0.0
# 12    0.0
# 13    0.0
# 14    0.8
# 15    0.0
# 16    0.9
# 17    0.2
# 18    0.0
# 19    0.0
# 20    0.0
# 21    0.0
# 22    0.0
# 23    0.1
# 24    0.0
# 25    0.0
# 26    0.0
# 27    0.0
# 28    0.0
# 29    0.0
# 30    0.0
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 30
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
# 6     0.0
# 7     0.0
# 8     0.1
# 9     0.9
# 10    0.7
# 11    0.0
# 12    0.0
# 13    0.0
# 14    0.8
# 15    0.0
# 16    0.9
# 17    0.2
# 18    0.0
# 19    0.0
# 20    0.0
# 21    0.0
# 22    0.0
# 23    0.1
# 24    0.0
# 25    0.0
# 26    0.0
# 27    0.0
# 28    0.0
# 29    0.0
# 30    0.0
# 31    0.0
# 32    0.0
# 33    0.0
# 34    0.0
# 35    0.0
# 36    0.0
# 37    0.4
# 38    0.0
# 39    0.0
# 40    0.6
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 40
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
# 6     0.0
# 7     0.0
# 8     0.1
# 9     0.9
# 10    0.7
# 11    0.0
# 12    0.0
# 13    0.0
# 14    0.8
# 15    0.0
# 16    0.9
# 17    0.2
# 18    0.0
# 19    0.0
# 20    0.0
# 21    0.0
# 22    0.0
# 23    0.1
# 24    0.0
# 25    0.0
# 26    0.0
# 27    0.0
# 28    0.0
# 29    0.0
# 30    0.0
# 31    0.0
# 32    0.0
# 33    0.0
# 34    0.0
# 35    0.0
# 36    0.0
# 37    0.4
# 38    0.0
# 39    0.0
# 40    0.6
# 41    0.0
# 42    0.0
# 43    0.0
# 44    0.0
# 45    0.0
# 46    1.0
# 47    1.0
# 48    0.6
# 49    0.0
# 50    0.1
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 50
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
# 6     0.0
# 7     0.0
# 8     0.1
# 9     0.9
# 10    0.7
# 11    0.0
# 12    0.0
# 13    0.0
# 14    0.8
# 15    0.0
# 16    0.9
# 17    0.2
# 18    0.0
# 19    0.0
# 20    0.0
# 21    0.0
# 22    0.0
# 23    0.1
# 24    0.0
# 25    0.0
# 26    0.0
# 27    0.0
# 28    0.0
# 29    0.0
# 30    0.0
# 31    0.0
# 32    0.0
# 33    0.0
# 34    0.0
# 35    0.0
# 36    0.0
# 37    0.4
# 38    0.0
# 39    0.0
# 40    0.6
# 41    0.0
# 42    0.0
# 43    0.0
# 44    0.0
# 45    0.0
# 46    1.0
# 47    1.0
# 48    0.6
# 49    0.0
# 50    0.1
# 51    0.0
# 52    0.0
# 53    0.0
# 54    0.0
# 55    0.0
# 56    0.0
# 57    0.0
# 58    0.0
# 59    0.0
# 60    0.0
# Name: score, dtype: float64
# <class 'pandas.Series'>
# 60
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
#      ...
# 66    0.0
# 67    0.8
# 68    0.7
# 69    0.0
# 70    0.7
# Name: score, Length: 70, dtype: float64
# <class 'pandas.Series'>
# 70
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
#      ...
# 76    0.6
# 77    0.0
# 78    0.3
# 79    0.3
# 80    0.3
# Name: score, Length: 80, dtype: float64
# <class 'pandas.Series'>
# 80
# id
# 1     0.9
# 2     0.9
# 3     0.0
# 4     0.0
# 5     0.4
#      ...
# 86    0.0
# 87    0.0
# 88    0.0
# 89    0.3
# 90    0.0
# Name: score, Length: 90, dtype: float64
# <class 'pandas.Series'>
# 90
# id
# 1      0.9
# 2      0.9
# 3      0.0
# 4      0.0
# 5      0.4
#       ...
# 96     0.0
# 97     0.0
# 98     1.0
# 99     0.3
# 100    0.1
# Name: score, Length: 100, dtype: float64
# <class 'pandas.Series'>
# 100

# %% [markdown]
# ---
# 1. At what n does the accuracy line start to feel stable?
# 2. Compare that number to the size of `MY_SUBSET` — are you in the reliable region?
# 3. Compare this curve to the one in 4.1. What is the difference in what K and n actually buy you?
#
# **Your answer:** Around n=60. Since the size of MY_SUBSET is over 200, we are in reliably region. K buys us nothing really, while n narrows the ci significantly.

# %% [markdown]
# ## 7. Comparing two models
#
# Reporting two accuracy numbers side by side doesn't tell you whether the gap is real
# or just noise. The paper (§4.2) describes a **paired test**: because both models answer
# the same questions, you can compute per-question score differences and test whether
# their mean differs significantly from zero. This removes question-difficulty variance
# and yields a lower standard error than treating the two runs as independent samples.

# %% [markdown]
# ## Assignment 5: Compare two models
#
# `run_and_get_scores` and `compare_models_paired` are provided. Complete
# `significance_by_paired_ttest` and use it to compare the two models on `MY_SUBSET`.
#
# Implement `significance_by_paired_ttest` and compare MODEL_A and MODEL_B.

# %%
import scipy
def run_and_get_scores(model_name: str, dataset, epochs: int = 1) -> np.ndarray:
    """Run eval and return mean-per-question scores, sorted by question id."""
    print(f"  Running {model_name} ...")
    run_logs = eval(mmlu_subset(dataset), model=model_name, epochs=epochs)
    df = log_to_df(run_logs[0])
    return df.groupby("id")["score"].mean().sort_index().values


def significance_by_paired_ttest(
    scores1: np.ndarray,
    scores2: np.ndarray,
    alpha: float = 0.05,
    two_tailed: bool = True,
) -> Tuple[float, float, bool]:
    """
    Paired t-test between two sets of per-question scores.

    Returns (p_value, mean_difference scores1 - scores2, is_significant).
    """
    assert len(scores1) == len(scores2), "arrays must cover the same questions"
    
    alternative = "two-sided" if two_tailed else "greater"
    
    p_value  = scipy.stats.ttest_rel(scores1, scores2, alternative=alternative).pvalue
    mean_diff   = (scores1 - scores2).mean()
    
    return p_value, mean_diff, bool(p_value < alpha)


def compare_models_paired(
    model_a: str,
    model_b: str,
    dataset,
    alpha: float = 0.05,
    two_tailed: bool = True,
    epochs_a: int = 1,
    epochs_b: int = 1,
) -> Tuple[float, float, bool, np.ndarray, np.ndarray ]:
    """
    Evaluate both models on the same dataset and run a paired t-test.

    Returns (p_value, mean_difference A - B, is_significant).

    Note: modified the opuput so that i do not need to rerun eval in the next assignment
    """
    scores_a = run_and_get_scores(model_a, dataset, epochs=epochs_a)
    scores_b = run_and_get_scores(model_b, dataset, epochs=epochs_b)
    p_val, mean_dif, is_sig = significance_by_paired_ttest(scores_a, scores_b, alpha, two_tailed)
    return p_val, mean_dif, is_sig, scores_a, scores_b

# %%
# =================================== TESTS ===================================
p, d, sig = significance_by_paired_ttest(np.array([1,2,3]), np.array([1,2,3]))

assert np.isclose(d, 0.0) and not sig

p, d, sig = significance_by_paired_ttest(
    np.array([1,1,1,1,1]), np.array([0,0,0,0,0]), two_tailed=False
)

assert sig and d > 0

print("All tests passed!")
# Out:
# All tests passed!

# %%
# Configure models -- replace with what is available in your environment.
# Examples: 'ollama/llama3.2', 'openai/gpt-4o-mini', 'anthropic/claude-haiku-4-5'

import os



MODEL_A = "ollama/llama2"        # weaker / baseline model
MODEL_B = "ollama/qwen2.5:0.5b" # stronger / comparison model



print(f"My subset: {len(MY_SUBSET)} questions")

p_value, mean_difference, is_significant, scores_a, scores_b = compare_models_paired(MODEL_B, MODEL_A, MY_SUBSET)

print("p value: ", p_value)
print("mean difference: ", mean_difference)
print("is significant: ", is_significant)
# Out:
# Output()
# [04/14/26 08:12:57] ERROR    Exception in callback Task.__step()                                ]8;id=20022;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=961399;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x71aa0a3530c0> is already entered
# My subset: 216 questions
#   Running ollama/qwen2.5:0.5b ...
# [04/14/26 08:22:38] ERROR    Task was destroyed but it is pending!                              ]8;id=890297;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=95704;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-2718'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:60> wait_for=<Task pending name='Task-2719'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# /usr/lib/python3.12/statistics.py:203: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   total = sum(Fraction(n, d) for d, n in partials.items())
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=589395;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=493905;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-2719' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#   Running ollama/llama2 ...
# Output()
# [04/14/26 08:33:34] ERROR    Exception in callback Task.__step()                                ]8;id=66173;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=985467;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x71aa0a3530c0> is already entered
# [04/14/26 08:33:47] ERROR    Task was destroyed but it is pending!                              ]8;id=216610;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=895364;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-4258'
#                              coro=<_async_in_context.<locals>.run_in_context() done, defined at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:57> wait_for=<Task pending name='Task-4259'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/anyio/abc/_sockets.py:147: RuntimeWarning:
# coroutine 'Kernel.shell_main' was never awaited
#   @property
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=469206;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=274634;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-4259' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# p value:  0.5749382501974498
# mean difference:  -0.023148148148148147
# is significant:  False

# %% [markdown]
# ---
# 1. Write down the p-value and the mean difference you got.
# 2. Is the gap significant? Is it large enough to matter in practice?
# 3. What would change your conclusion: more questions, a different subject, or a different model pair?
#
# **Your answer:**

# %% [markdown]
# ## 8. Interval estimation of the accuracy difference
#
# In Assignment 5 you got a yes/no significance decision. Here you will estimate the size of the gap and its uncertainty: a confidence interval on the difference gives both pieces of information at once.
#
# ## Assignment 6: Estimate the accuracy gap
#
# Use `ci_accuracy_basic` to compute a 95% CI on the per-question score differences.
#
# Compute and report the confidence interval on MODEL_A − MODEL_B.

# %%
per_question_diff = scores_a-scores_b
ci_lower, mean, ci_upper = ci_accuracy_basic(per_question_diff)
print("ci_lower: ", ci_lower)
print("mean: ", mean)
print("ci_upper: ", ci_upper)
# Out:
# ci_lower:  -0.10392690427056456
# mean:  -0.023148148148148147
# ci_upper:  0.05763060797426827

# %% [markdown]
# ---
# 1. Write down the interval. Does it contain zero?
# 2. How does this relate to the significance test in Assignment 5 — do they tell the same story?
# 3. Which result is more informative — the p-value or the interval? Why?
#
# **Your answer:**

# %% [markdown]
# ## 9. Power analysis
#
# Before running an expensive evaluation, it is worth asking: how many questions do we
# need to detect a meaningful difference with adequate statistical power?
# The paper (§5) derives the minimum detectable effect as a function of sample size n,
# question-level variance ω², and within-model variance σ².
#
# ## Assignment 7: 'Estimate variance components'
#
# Implement `estimate_variance_components` and report the MDE for `MY_SUBSET` at α = 0.05, power = 80%.

# %%
def var(scores: list) -> float:
    n = len(scores)
    if n==0 or n==1:
        raise ValueError("scores must contain at least 2 observations")
    mean_accuracy = np.mean(scores)

    var = (1/(n-1))*sum((score - mean_accuracy)**2 for score in scores)
    return var

def estimate_variance_components(
    logs_a: List[EvalLog],
    logs_b: List[EvalLog],
) -> dict:
    """
    Estimate omega2, sigma2_a, sigma2_b from two EvalLog objects (see ss5 of the paper).

    Both logs must cover the same set of questions. Use epochs >= 2 so that
    within-question variance can be estimated.

    Returns dict with keys 'omega2', 'sigma2_a', 'sigma2_b'.
    """
    df_a = log_to_df(logs_a[0])
    df_b = log_to_df(logs_b[0])
    ids_a = {gid for gid,_ in df_a.groupby("id")}
    ids_b = {gid for gid,_ in df_b.groupby("id")}
    assert ids_a == ids_b
    per_question_mean_a = {gid: g["score"].mean() for gid,g in df_a.groupby("id")}
    per_question_mean_b = {gid: g["score"].mean() for gid,g in df_b.groupby("id")}
    per_question_mean_diff = {gid: per_question_mean_a[gid] - per_question_mean_b[gid] for gid in ids_a}
    sigma2_a = np.mean([var(g["score"].to_list()) for _,g in df_a.groupby("id")])
    sigma2_b = np.mean([var(g["score"].to_list()) for _,g in df_b.groupby("id")])

    omega2 = var(list(per_question_mean_diff.values()))

    return {
        "omega2":   omega2,
        "sigma2_a": sigma2_a,
        "sigma2_b": sigma2_b,
    }


def minimum_detectable_effect(
    n: int,
    omega2: float,
    sigma2_a: float = 0.0,
    sigma2_b: float = 0.0,
    ka: int = 1,
    kb: int = 1,
    alpha: float = 0.05,
    power: float = 0.80,
) -> float:
    """MDE for a paired model comparison (Eq. 10 in the paper)."""
    z_alpha = stats.norm.ppf(1 - alpha / 2)
    z_beta  = stats.norm.ppf(power)
    return float((z_alpha + z_beta) * np.sqrt(
        (omega2 + sigma2_a / ka + sigma2_b / kb) / n
    ))

# %%
print("Running pilot evals ...")
logs_a = eval(mmlu_subset(MY_SUBSET), model=MODEL_A, epochs=2, limit=15)
logs_b = eval(mmlu_subset(MY_SUBSET), model=MODEL_B, epochs=2, limit=15)

params = estimate_variance_components(logs_a, logs_b)
print(f"omega2  = {params['omega2']:.4f}")
print(f"sigma2_A = {params['sigma2_a']:.4f}")
print(f"sigma2_B = {params['sigma2_b']:.4f}")

mde = minimum_detectable_effect(n=len(MY_SUBSET), **params)
print(f"\nWith n={len(MY_SUBSET)} questions -> MDE = {mde:.1%}")
print("(smallest gap detectable at 80% power, alpha=0.05)")
# Out:
# Output()
# [04/14/26 09:56:25] ERROR    Exception in callback Task.__step()                                ]8;id=392390;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=913961;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x71aa0a3530c0> is already entered
# Running pilot evals ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# [04/14/26 09:59:15] ERROR    Exception in callback Task.__step()                                ]8;id=341485;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=158487;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x71aa0a3530c0> is already entered
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# omega2  = 0.2667
# sigma2_A = 0.0667
# sigma2_B = 0.1667
#
# With n=216 questions -> MDE = 13.5%
# (smallest gap detectable at 80% power, alpha=0.05)

# %% [markdown]
# ---
# 1. What MDE did you get for `MY_SUBSET`? Is that gap practically meaningful?
# 2. If the MDE is larger than the gap you observed in Assignment 5,
#    what does that say about your earlier result?
#
# **Your answer:**

# %% [markdown]
# ## Assignment 8: Implement `required_sample_size`
#
# `minimum_detectable_effect` computes delta given n. Implement its inverse:
# given a target delta, return the minimum n needed. Use the sample-size formula
# from ss5 of the paper (Eq. 9). Verify it passes the round-trip check,
# then use it to compute how many questions you would need to detect a 5% and a 10%
# accuracy gap on `MY_SUBSET`.

# %%
# --- Assignment 7 -----------------------------------------------------------
def required_sample_size(
    delta: float,
    omega2: float,
    sigma2_a: float = 0.0,
    sigma2_b: float = 0.0,
    ka: int = 1,
    kb: int = 1,
    alpha: float = 0.05,
    power: float = 0.80,
) -> int:
    """Minimum number of questions needed to detect `delta` at the given power."""
    z_alpha = stats.norm.ppf(1 - alpha / 2)
    z_beta  = stats.norm.ppf(power)
    n = ((z_alpha + z_beta)**2)*(omega2+sigma2_a/ka + sigma2_b/kb)/delta**2
    return n


# =================================== TESTS ===================================
n_needed = required_sample_size(delta=0.05, **params)
print(f"Questions needed to detect delta=5%: {n_needed}")

mde_check = minimum_detectable_effect(n=n_needed, **params)

assert abs(mde_check - 0.05) < 0.005, f"Round-trip failed: MDE={mde_check:.3f}"

print("Round-trip check passed!")
# Out:
# Questions needed to detect delta=5%: 1569.7759468698177
# Round-trip check passed!

# %%
print("required sample size for 5% gap:", required_sample_size(0.05, **params))
print("required sample size for 10% gap:", required_sample_size(0.1, **params))
# Out:
# required sample size for 5% gap: 1569.7759468698177
# required sample size for 10% gap: 392.44398671745444

# %% [markdown]
# ---
# 1. How many questions do you need to detect a 5% gap? A 10% gap?
# 2. Does `MY_SUBSET` have enough questions to be a useful benchmark for comparing these two models?
#
# **Your answer:**

# %% [markdown]
# ## Assignment 9: Compare a model with itself: baseline vs chain-of-thought
#
# The `multiple_choice()` solver we have used so far prompts the model to answer
# directly. inspect_ai also provides a `chain_of_thought` that asks the model
# to reason step by step before giving its final answer.
#
# Using the paired comparison infrastructure from Section 7, evaluate the same model
# twice on the same subset — once with the default solver and once with
# `chain_of_thought` — and test whether the difference in accuracy is statistically
# significant. Does reasoning help? Is the effect consistent across subjects?

# %%
logs = eval(mmlu_subset(MY_SUBSET), model=MODEL_A, epochs=3)
logs_cot = eval(mmlu_subset(MY_SUBSET), model=MODEL_A, epochs=3, solver=chain_of_thought())

df = log_to_df(logs[0])
scores = df.groupby("id")["score"].mean().sort_index().values

df_cot = log_to_df(logs_cot[0])
scores_cot = df.groupby("id")["score"].mean().sort_index().values

p_value, mean_difference, is_significant = significance_by_paired_ttest(scores, scores_cot)

print("p value: ", p_value)
print("mean difference: ", mean_difference)
print("is significant: ", is_significant)

params = estimate_variance_components(logs, logs_cot)
print(f"omega2  = {params['omega2']:.4f}")
print(f"sigma2_A = {params['sigma2_a']:.4f}")
print(f"sigma2_B = {params['sigma2_b']:.4f}")

mde = minimum_detectable_effect(n=len(MY_SUBSET), **params)
# Out:
# Output()
# [04/14/26 11:16:32] ERROR    Exception in callback Task.__step()                                ]8;id=841202;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=981192;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              handle: <Handle Task.__step()>
#                              Traceback (most recent call last):
#                                File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#                                  self._context.run(self._callback, *self._args)
#                              RuntimeError: cannot enter context: <_contextvars.Context object
#                              at 0x7dae404daa40> is already entered
# [04/14/26 11:33:43] ERROR    Task was destroyed but it is pending!                              ]8;id=246454;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=244515;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-685' coro=<Kernel.shell_main()
#                              running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
# /usr/lib/python3.12/statistics.py:193: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   for n, d in map(_exact_ratio, values):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
#                     ERROR    Task was destroyed but it is pending!                              ]8;id=383077;file:///usr/lib/python3.12/asyncio/base_events.py\base_events.py]8;;\:]8;id=78917;file:///usr/lib/python3.12/asyncio/base_events.py#1821\1821]8;;\
#                              task: <Task pending name='Task-664'
#                              coro=<_async_in_context.<locals>.run_in_context() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/utils.py:60> wait_for=<Task pending name='Task-685'
#                              coro=<Kernel.shell_main() running at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              ipykernel/kernelbase.py:597> cb=[Task.__wakeup()]>
#                              cb=[ZMQStream._run_callback.<locals>._log_error() at
#                              /home/user/Documents/ai-safety/.venv/lib/python3.12/site-packages/
#                              zmq/eventloop/zmqstream.py:563]>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# p value:  nan
# mean difference:  0.0
# is significant:  False
# omega2  = 0.1431
# sigma2_A = 0.0617
# sigma2_B = 0.0000

# %% [markdown]
# ---
# 1. Does chain-of-thought help? By how much, and is it significant?
# 2. Does the result surprise you? What might explain it?
# 3. Would you expect the same pattern on a different subject?
#
# **Your answer:**

# %% [markdown]
# ## Bonus assignment: Clustered Standard Errors
#
# Some benchmarks contain groups of related questions — for example, several questions
# about the same passage in reading comprehension tasks like DROP or RACE. In such cases
# the standard CLT confidence interval is anti-conservative: questions within a group are
# correlated, so the effective sample size is smaller than n. Miller (2024) addresses this
# with clustered standard errors (§2.2).
#
# Using a reading comprehension benchmark of your choice, implement the clustered
# confidence interval (Eq. 4 from the paper) and compare it against the naive CLT interval.
# How much wider is the clustered interval? Does the difference depend on the benchmark?
# Then compare two models on the same benchmark using the clustered paired standard error
# (Eq. 8) — does the conclusion about which model is better change compared to the
# naive paired test?

# %%
# YOUR CODE HERE
